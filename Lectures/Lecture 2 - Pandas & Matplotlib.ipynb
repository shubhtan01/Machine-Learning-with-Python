# %% [markdown]
# ### Importing library

# %%
import pandas as pd

# %% [markdown]
# ### Importing datasets

# %%
df = pd.read_csv("HIMYMdataset.csv")

# %% [markdown]
# ### Viewing data

# %%
df
# Out:
#      SNo  Season  Episode  DateAired                   Title       Director  \
# 0      1       1        1  19-Sep-05                   Pilot  Pamela Fryman
# 1      2       1        2  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2      3       1        3   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 3      4       1        4  10-Oct-05     Return of the Shirt  Pamela Fryman
# 4      5       1        5  17-Oct-05            Okay Awesome  Pamela Fryman
# ..   ...     ...      ...        ...                     ...            ...
# 203  204       9       20  10-Mar-14                   Daisy  Pamela Fryman
# 204  205       9       21  17-Mar-14            Gary Blauman  Pamela Fryman
# 205  206       9       22  24-Mar-14    The End of the Aisle  Pamela Fryman
# 206  207       9       23  31-Mar-14    Last Forever, Part 1  Pamela Fryman
# 207  208       9       24  31-Mar-14    Last Forever, Part 2  Pamela Fryman
#
# ...

# %%
df.head()
# Out:
#    SNo  Season  Episode  DateAired                   Title       Director  \
# 0    1       1        1  19-Sep-05                   Pilot  Pamela Fryman
# 1    2       1        2  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2    3       1        3   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 3    4       1        4  10-Oct-05     Return of the Shirt  Pamela Fryman
# 4    5       1        5  17-Oct-05            Okay Awesome  Pamela Fryman
#
#                     Writers  Viewers  IMDB_Rating  Votes
# 0  Carter Bays,Craig Thomas    10.94          8.5   4935
# 1  Carter Bays,Craig Thomas    10.40          8.2   3708
# 2    Phil Lord,Chris Miller    10.44          8.2   3514
# 3             Kourtney Kang     9.84          8.0   3298
# 4              Chris Harris    10.14          8.3   3412

# %%
df.head(10)
# Out:
#    SNo  Season  Episode  DateAired                   Title       Director  \
# 0    1       1        1  19-Sep-05                   Pilot  Pamela Fryman
# 1    2       1        2  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2    3       1        3   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 3    4       1        4  10-Oct-05     Return of the Shirt  Pamela Fryman
# 4    5       1        5  17-Oct-05            Okay Awesome  Pamela Fryman
# 5    6       1        6  24-Oct-05          Slutty Pumpkin  Pamela Fryman
# 6    7       1        7   7-Nov-05              Matchmaker  Pamela Fryman
# 7    8       1        8  14-Nov-05                The Duel  Pamela Fryman
# 8    9       1        9  21-Nov-05    Belly Full of Turkey  Pamela Fryman
# 9   10       1       10  28-Nov-05  The Pineapple Incident  Pamela Fryman
#
#                     Writers  Viewers  IMDB_Rating  Votes
# 0  Carter Bays,Craig Thomas    10.94          8.5   4935
# ...

# %%
df.tail()
# Out:
#      SNo  Season  Episode  DateAired                 Title       Director  \
# 203  204       9       20  10-Mar-14                 Daisy  Pamela Fryman
# 204  205       9       21  17-Mar-14          Gary Blauman  Pamela Fryman
# 205  206       9       22  24-Mar-14  The End of the Aisle  Pamela Fryman
# 206  207       9       23  31-Mar-14  Last Forever, Part 1  Pamela Fryman
# 207  208       9       24  31-Mar-14  Last Forever, Part 2  Pamela Fryman
#
#                       Writers  Viewers  IMDB_Rating  Votes
# 203  Carter Bays,Craig Thomas     7.70          8.5   2890
# 204             Kourtney Kang     7.78          8.3   2981
# 205  Carter Bays,Craig Thomas     9.04          8.9   3848
# 206  Carter Bays,Craig Thomas    13.13          6.7   8625
# 207  Carter Bays,Craig Thomas    13.13          5.5  15760

# %%
df.tail(10)
# Out:
#      SNo  Season  Episode  DateAired                   Title       Director  \
# 198  199       9       15  20-Jan-14                 Unpause  Pamela Fryman
# 199  200       9       16  27-Jan-14  How Your Mother Met Me  Pamela Fryman
# 200  201       9       17   3-Feb-14                 Sunrise  Pamela Fryman
# 201  202       9       18  24-Feb-14                   Rally  Pamela Fryman
# 202  203       9       19   3-Mar-14                Vesuvius  Pamela Fryman
# 203  204       9       20  10-Mar-14                   Daisy  Pamela Fryman
# 204  205       9       21  17-Mar-14            Gary Blauman  Pamela Fryman
# 205  206       9       22  24-Mar-14    The End of the Aisle  Pamela Fryman
# 206  207       9       23  31-Mar-14    Last Forever, Part 1  Pamela Fryman
# 207  208       9       24  31-Mar-14    Last Forever, Part 2  Pamela Fryman
#
#                       Writers  Viewers  IMDB_Rating  Votes
# 198              Chris Harris     8.83          8.4   2983
# ...

# %% [markdown]
# ### Analysing data

# %%
df.columns
# Out:
# Index(['SNo', 'Season', 'Episode', 'DateAired', 'Title', 'Director', 'Writers',
#        'Viewers', 'IMDB_Rating', 'Votes'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SNo              int64
# Season           int64
# Episode          int64
# DateAired       object
# Title           object
# Director        object
# Writers         object
# Viewers        float64
# IMDB_Rating    float64
# Votes            int64
# dtype: object

# %%
df.describe()
# Out:
#               SNo      Season     Episode     Viewers  IMDB_Rating  \
# count  208.000000  208.000000  208.000000  205.000000    206.00000
# mean   104.500000    5.105769   12.096154    9.040634      8.15534
# std     60.188592    2.574187    6.748081    1.226919      0.57843
# min      1.000000    1.000000    1.000000    6.410000      5.50000
# 25%     52.750000    3.000000    6.000000    8.120000      7.80000
# 50%    104.500000    5.000000   12.000000    8.870000      8.10000
# 75%    156.250000    7.000000   18.000000    9.900000      8.50000
# max    208.000000    9.000000   24.000000   13.130000      9.50000
#
#               Votes
# count    208.000000
# mean    2917.403846
# std     1191.640598
# min     2182.000000
# 25%     2456.750000
# 50%     2646.500000
# 75%     2949.500000
# max    15760.000000

# %%
df.describe(include='int64')
# Out:
#               SNo      Season     Episode         Votes
# count  208.000000  208.000000  208.000000    208.000000
# mean   104.500000    5.105769   12.096154   2917.403846
# std     60.188592    2.574187    6.748081   1191.640598
# min      1.000000    1.000000    1.000000   2182.000000
# 25%     52.750000    3.000000    6.000000   2456.750000
# 50%    104.500000    5.000000   12.000000   2646.500000
# 75%    156.250000    7.000000   18.000000   2949.500000
# max    208.000000    9.000000   24.000000  15760.000000

# %% [markdown]
# ### Working with columns

# %%
df2 = df['Viewers']
df2.head()
# Out:
# 0    10.94
# 1    10.40
# 2    10.44
# 3     9.84
# 4    10.14
# Name: Viewers, dtype: float64

# %%
df3 = df[['Title', 'Director', 'Writers']]
df3.head()
# Out:
#                     Title       Director                   Writers
# 0                   Pilot  Pamela Fryman  Carter Bays,Craig Thomas
# 1          Purple Giraffe  Pamela Fryman  Carter Bays,Craig Thomas
# 2  Sweet Taste of Liberty  Pamela Fryman    Phil Lord,Chris Miller
# 3     Return of the Shirt  Pamela Fryman             Kourtney Kang
# 4            Okay Awesome  Pamela Fryman              Chris Harris

# %%
df3['Writers'].unique()
# Out:
# array(['Carter Bays,Craig Thomas', 'Phil Lord,Chris Miller',
#        'Kourtney Kang', 'Chris Harris', 'Brenda Hsueh',
#        'Sam Johnson,Chris Marcil', 'Gloria Calderon Kellett',
#        'Maria Ferrari', 'Ira Ungerleider', 'Stephen Lloyd',
#        'Kristen Newman', 'Jamie Rhonheimer', 'Greg Malins', 'Matt Kuhn',
#        'David Hemingson', 'Jonathan Groff',
#        'Chris Harris, Carter Bays,Craig Thomas', 'Joe Kelly',
#        'Jonathan Groff,Chris Harris', 'Robia Rashid',
#        'Theresa Mulligan Rosenthal', 'Chuck Tatham',
#        'Craig Gerard,Matthew Zinman', 'Jennifer Hendriks', 'Tami Sagher',
#        'Tom Ruprecht', 'Dan Gregor,Doug Mand', 'George Sloan',
#        'Eric Falconer,Romanski', 'Barbara Adler', 'Rachel Axler'],
#       dtype=object)

# %% [markdown]
# ### Working with rows

# %%
df4=df[(df['IMDB_Rating']>8)]
df4.head()
# Out:
#    SNo  Season  Episode  DateAired                   Title       Director  \
# 0    1       1        1  19-Sep-05                   Pilot  Pamela Fryman
# 1    2       1        2  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2    3       1        3   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 4    5       1        5  17-Oct-05            Okay Awesome  Pamela Fryman
# 5    6       1        6  24-Oct-05          Slutty Pumpkin  Pamela Fryman
#
#                     Writers  Viewers  IMDB_Rating  Votes
# 0  Carter Bays,Craig Thomas    10.94          8.5   4935
# 1  Carter Bays,Craig Thomas    10.40          8.2   3708
# 2    Phil Lord,Chris Miller    10.44          8.2   3514
# 4              Chris Harris    10.14          8.3   3412
# 5              Brenda Hsueh    10.89          8.1   3292

# %%
df5=df[(df['IMDB_Rating']>8) & (df['Writers']=="Chris Harris")]
df5.head()
# Out:
#     SNo  Season  Episode  DateAired                      Title       Director  \
# 4     5       1        5  17-Oct-05               Okay Awesome  Pamela Fryman
# 14   15       1       15  27-Feb-06                 Game Night  Pamela Fryman
# 18   19       1       19  24-Apr-06         Mary the Paralegal  Pamela Fryman
# 23   24       2        2  25-Sep-06  The Scorpion and the Toad  Rob Greenberg
# 38   39       2       17  26-Feb-07         Arrivederci, Fiero  Pamela Fryman
#
#          Writers  Viewers  IMDB_Rating  Votes
# 4   Chris Harris    10.14          8.3   3412
# 14  Chris Harris     9.82          9.1   3780
# 18  Chris Harris     7.60          8.8   3337
# 23  Chris Harris     9.14          8.2   2725
# 38  Chris Harris     9.33          8.3   2775

# %% [markdown]
# ### Indexing and Slicing

# %%
df.loc[9,'Title']
# Out:
# 'The Pineapple Incident'

# %%
df.iloc[9,4]
# Out:
# 'The Pineapple Incident'

# %%
df.iloc[10:20,4:7]
# Out:
#                                 Title       Director                   Writers
# 10                           The Limo  Pamela Fryman  Sam Johnson,Chris Marcil
# 11                        The Wedding  Pamela Fryman             Kourtney Kang
# 12                   Drumroll, Please  Pamela Fryman   Gloria Calderon Kellett
# 13                      Zip, Zip, Zip  Pamela Fryman              Brenda Hsueh
# 14                         Game Night  Pamela Fryman              Chris Harris
# 15                            Cupcake  Pamela Fryman             Maria Ferrari
# 16            Life Among the Gorillas  Pamela Fryman  Carter Bays,Craig Thomas
# 17  Nothing Good Happens After 2 A.M.  Pamela Fryman  Carter Bays,Craig Thomas
# 18                 Mary the Paralegal  Pamela Fryman              Chris Harris
# 19                     Best Prom Ever  Pamela Fryman           Ira Ungerleider

# %%
df.iloc[-5:-1,4:7]
# Out:
#                     Title       Director                   Writers
# 203                 Daisy  Pamela Fryman  Carter Bays,Craig Thomas
# 204          Gary Blauman  Pamela Fryman             Kourtney Kang
# 205  The End of the Aisle  Pamela Fryman  Carter Bays,Craig Thomas
# 206  Last Forever, Part 1  Pamela Fryman  Carter Bays,Craig Thomas

# %%
df.iloc[:,4]
# Out:
# 0                       Pilot
# 1              Purple Giraffe
# 2      Sweet Taste of Liberty
# 3         Return of the Shirt
# 4                Okay Awesome
#                 ...
# 203                     Daisy
# 204              Gary Blauman
# 205      The End of the Aisle
# 206      Last Forever, Part 1
# 207      Last Forever, Part 2
# Name: Title, Length: 208, dtype: object

# %% [markdown]
# ### Exporting data

# %%
df.to_csv("NewDataset.csv")

# %% [markdown]
# ### Creating Dataframe from Dictionary

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

dfnew = pd.DataFrame(data)
dfnew.head()
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# ### Cleaning data

# %%
df.isnull().sum()
# Out:
# SNo            0
# Season         0
# Episode        0
# DateAired      0
# Title          0
# Director       0
# Writers        0
# Viewers        3
# IMDB_Rating    2
# Votes          0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# SNo            0
# Season         0
# Episode        0
# DateAired      0
# Title          0
# Director       0
# Writers        0
# Viewers        0
# IMDB_Rating    0
# Votes          0
# dtype: int64

# %%
x = df["Viewers"].mean()
df["Viewers"].fillna(x, inplace = True)
df.head()
# Out:
#    SNo  Season  Episode  DateAired                   Title       Director  \
# 0    1       1        1  19-Sep-05                   Pilot  Pamela Fryman
# 1    2       1        2  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2    3       1        3   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 3    4       1        4  10-Oct-05     Return of the Shirt  Pamela Fryman
# 4    5       1        5  17-Oct-05            Okay Awesome  Pamela Fryman
#
#                     Writers  Viewers  IMDB_Rating  Votes
# 0  Carter Bays,Craig Thomas    10.94          8.5   4935
# 1  Carter Bays,Craig Thomas    10.40          8.2   3708
# 2    Phil Lord,Chris Miller    10.44          8.2   3514
# 3             Kourtney Kang     9.84          8.0   3298
# 4              Chris Harris    10.14          8.3   3412

# %%
df = df.drop('Episode',axis=1)
df.head()
# Out:
#    SNo  Season  DateAired                   Title       Director  \
# 0    1       1  19-Sep-05                   Pilot  Pamela Fryman
# 1    2       1  26-Sep-05          Purple Giraffe  Pamela Fryman
# 2    3       1   3-Oct-05  Sweet Taste of Liberty  Pamela Fryman
# 3    4       1  10-Oct-05     Return of the Shirt  Pamela Fryman
# 4    5       1  17-Oct-05            Okay Awesome  Pamela Fryman
#
#                     Writers  Viewers  IMDB_Rating  Votes
# 0  Carter Bays,Craig Thomas    10.94          8.5   4935
# 1  Carter Bays,Craig Thomas    10.40          8.2   3708
# 2    Phil Lord,Chris Miller    10.44          8.2   3514
# 3             Kourtney Kang     9.84          8.0   3298
# 4              Chris Harris    10.14          8.3   3412

# %% [markdown]
# ### Converting Pandas Dataframe to Numpy Arrays

# %%
x = df['Votes'].to_numpy()
print(x)
print(type(x))
# Out:
# [ 4935  3708  3514  3298  3412  3292  3095  3057  3070  4667  2988  3384
#   2906  3780  2806  2793  3066  3337  2790  2794  3455  2788  2725  2833
#   3213  3033  3806  2661  5571  2725  2696  2773  2564  2744  2680  2811
#   2775  2561  2690  2936  2779  2832  2512  2609  2506  3468  2483  2522
#   3450  3321  2656  2570  3072  2695  2463  2707  2481  2450  2460  2667
#   2866  2989  2454  2920  2556  2442  2390  2562  4075  2526  2495  2693
#   2649  2551  2604  2466  2352  2551  2380  2660  2472  2396  2827  2727
#   2446  2526  2580  2393  2318  2446  5262  2533  2467  2584  4141  2717
#   2947  2426  2382  2664  2444  2384  2372  2316  2454  2590  2508  2620
#   2619  2342  2698  2296  2307  2272  2383  2804  3762  2416  2368  3414
#   2830  3174  2327  2200  2411  2543  2225  2225  2240  2182  2565  3262
#   2587  3260  2440  2315  2416  2411  2478  2584  3642  2456  3302  2452
#   2522  2660  2517  2647  2330  2738  2629  2254  2189  2650  3097  4102
# ...

# %%
x = df['Votes'].values
print(x)
print(type(x))
# Out:
# [ 4935  3708  3514  3298  3412  3292  3095  3057  3070  4667  2988  3384
#   2906  3780  2806  2793  3066  3337  2790  2794  3455  2788  2725  2833
#   3213  3033  3806  2661  5571  2725  2696  2773  2564  2744  2680  2811
#   2775  2561  2690  2936  2779  2832  2512  2609  2506  3468  2483  2522
#   3450  3321  2656  2570  3072  2695  2463  2707  2481  2450  2460  2667
#   2866  2989  2454  2920  2556  2442  2390  2562  4075  2526  2495  2693
#   2649  2551  2604  2466  2352  2551  2380  2660  2472  2396  2827  2727
#   2446  2526  2580  2393  2318  2446  5262  2533  2467  2584  4141  2717
#   2947  2426  2382  2664  2444  2384  2372  2316  2454  2590  2508  2620
#   2619  2342  2698  2296  2307  2272  2383  2804  3762  2416  2368  3414
#   2830  3174  2327  2200  2411  2543  2225  2225  2240  2182  2565  3262
#   2587  3260  2440  2315  2416  2411  2478  2584  3642  2456  3302  2452
#   2522  2660  2517  2647  2330  2738  2629  2254  2189  2650  3097  4102
# ...

# %%
x = df[['Viewers', 'IMDB_Rating', 'Votes']].values
print(type(x))
print(x.shape)
# Out:
# <class 'numpy.ndarray'>
# (203, 3)

# %% [markdown]
# ## Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],[1,8,27,64],'b^')
plt.xlabel("x-axis")
plt.ylabel("Y-axis")
plt.title("Our plot")
plt.show()

# %%
plt.plot(df["IMDB_Rating"],df["Viewers"],'go')
